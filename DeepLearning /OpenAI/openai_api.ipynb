# %%
   # openai is a official python module of OpenAI through which we access our openAI API

# %%
# prompt => openai => response

# %%
OPENAI_API_KEY="API KEY"

# %%
from openai import OpenAI

client = OpenAI(
    api_key=OPENAI_API_KEY
)

models = client.models.list()

for model in models.data:
    print(model.id)
# Out:
# text-embedding-ada-002
# whisper-1
# gpt-3.5-turbo
# tts-1
# gpt-3.5-turbo-16k
# davinci-002
# babbage-002
# gpt-3.5-turbo-instruct
# gpt-3.5-turbo-instruct-0914
# gpt-3.5-turbo-1106
# tts-1-hd
# tts-1-1106
# tts-1-hd-1106
# text-embedding-3-small
# text-embedding-3-large
# gpt-3.5-turbo-0125
# gpt-4o
# gpt-4o-2024-05-13
# gpt-4o-mini-2024-07-18
# gpt-4o-mini
# gpt-4o-2024-08-06
# omni-moderation-latest
# omni-moderation-2024-09-26
# o1-2024-12-17
# o1
# o3-mini
# o3-mini-2025-01-31
# gpt-4o-2024-11-20
# gpt-4o-mini-search-preview-2025-03-11
# gpt-4o-mini-search-preview
# gpt-4o-transcribe
# gpt-4o-mini-transcribe
# gpt-4o-mini-tts
# o3-2025-04-16
# o4-mini-2025-04-16
# o3
# o4-mini
# gpt-4.1-2025-04-14
# gpt-4.1
# gpt-4.1-mini-2025-04-14
# gpt-4.1-mini
# gpt-4.1-nano-2025-04-14
# gpt-4.1-nano
# gpt-image-1
# gpt-4o-transcribe-diarize
# gpt-5-chat-latest
# gpt-5-2025-08-07
# gpt-5
# gpt-5-mini-2025-08-07
# gpt-5-mini
# gpt-5-nano-2025-08-07
# gpt-5-nano
# gpt-audio-2025-08-28
# ...

# %%
# this form is helpful when we want to give a personality to AI assistant

response = client.responses.create(
    model="gpt-5.6",
    input=[
        {
            "role":"system",
            "content":"act like a teacher"
        },
        {
         "role":"user",
         "content":"a+2=7, find a"
        }
     ]
)
print(response.output_text)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[24], line 3
#       1 # this form is helpful when we want to give a personality to AI assistant
#       2
# ----> 3 response = client.responses.create(
#       4     model="gpt-5.6",
#       5     input=[
#       6         {
#
# File ~\.conda\envs\deeplearning\Lib\site-packages\openai\resources\responses\responses.py:1031, in Responses.create(self, background, context_management, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, moderation, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#     989 def create(
# ...

# %%
response = client.responses.create(
    model="groq/compound",
    input="a+2=7, find a"
)
print(response.output_text)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 response = client.responses.create(
#       2     model="groq/compound",
#       3     input="a+2=7, find a"
#       4 )
#
# File ~\.conda\envs\deeplearning\Lib\site-packages\openai\resources\responses\responses.py:1031, in Responses.create(self, background, context_management, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, moderation, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#     989 def create(
#     990     self,
#     991     *,
# ...

# %%
response

# %%
client.chat.completions.create(
    model="meta-llama/llama-4-scout-17b-16e-instruct",
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": "Which country's flag is in the image?"
                },
                {
                    "type": "image_url",
                    "image_url": {
                        "url": "https://example.com/image.jpg"
                    }
                }
            ]
        }
    ]
)

# %% [markdown]
# ### AI PERSONAL ASSISTANT

# %%
# defining the scope of it ->
# queries -> answer
# emails -> summarize

class PersonalAssistant:
    def __init__(self):
        print("Hi, I am your AI Assistant. How can i help you?")

    def ans_query(self):
        question=input("ask me anything: ")
        response=client.responses.create(
            model="gpt-5.4",
            input=[
                {"role":"system", "content":"Act like a helpful personal assistant"},
                {"role":"user", "content":question}
            ],
            temperature=0.7,
            max_output_tokens=512
        )

        print(response.output_text.strip())

    def summarize_email(self):
        email_text=input("paste email here: ")
        prompt=f"summarize the email in 2-3 sentences: {email_text}"
        response=client.responses.create(
            model="gpt-5.4",
            input=[
                {"role":"system", "content":"Act like an expert email assistant"},
                {"role":"user", "content":prompt}
            ],
            temperature=0.3,
            max_output_tokens=512
        )

        print(response.output_text.strip())

# %%
assistant=PersonalAssistant()

# %%
assistant.summarize_email()

# %% [markdown]
# ## Images in OpenAI

# %% [markdown]
# ### Responses API

# %%
import base64
# images => base64 encoded string => decode to see them

# %%
 response=client.responses.create(
            model="gpt-5",
            input="Generate an image of a highly detailed futuristic spaceship, flying near a nebula"
            tools=[{"type":"image_generation"}]
        )
image_data=[
    output.result
    for output in response.output
    if output.type=="image_generation_call"
]
# decode and store image in a file
if image_data:
    image_base64=image_data[0]
    with open("spaceship.png","wb") as f:
        image_bytes=base64.b64decode(image_base64)
        f.write(image_bytes)
# Out:
#   Cell In[2], line 1
#     response=client.responses.create(
#     ^
# IndentationError: unexpected indent

# %%
### Image API

prompt = """
Generate an image of a highly detailed futuristic spaceship, flying near a nebula
"""

result = client.images.generate(model="gpt-image-2", prompt=prompt)

image_base64 = result.data[0].b64_json
image_bytes = base64.b64decode(image_base64)

# Save the image to a file
with open("spaceship-img.png", "wb") as f:
    f.write(image_bytes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       3 prompt = """
#       4 Generate an image of a highly detailed futuristic spaceship, flying near a nebula
#       5 """
#       6
# ----> 7 result = client.images.generate(model="gpt-image-2", prompt=prompt)
#       8
#       9 image_base64 = result.data[0].b64_json
#      10 image_bytes = base64.b64decode(image_base64)
#
# NameError: name 'client' is not defined

# %%
# Edit the image

prompt = """
Take the Reference image and convert the spaceship color to red
"""

result = client.images.edit(
    model="gpt-image-2",
    prompt=prompt
    image=[
        open("spaceship-image.png","rb")
    ]
)

image_base64 = result.data[0].b64_json
image_bytes = base64.b64decode(image_base64)

# Save the image to a file
with open("spaceship-red.png", "wb") as f:
    f.write(image_bytes)
